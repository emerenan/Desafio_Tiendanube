# %% [markdown]
# <a href="https://colab.research.google.com/github/emerenan/Desafio_Tiendanube/blob/master/validador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def readfile(path):
    """ Método para leitura de arquivo no formato .csv
    
    Parametros \n
    |param path: caminho onde o arquivo está localizado. \n


    """
    try:
        df = pd.read_csv(path, sep=';', error_bad_lines=False, warn_bad_lines=True)
        print(df.head())
        print('-----------------------------------------------------------------------')
        print(df.isnull().sum())
        print('-----------------------------------------------------------------------')
        print(df.info())
        print('-----------------------------------------------------------------------')
        return df
    
    except pd.io.common.ParserError:
        print("Dados não lidos")

data_co = readfile('/content/310522_CO_012020_072020.csv')
data_si = readfile('/content/310522_SI_012020_062020.csv')
data_be = readfile('/content/310522_BE_160420.csv')
data_pl = readfile('/content/310522_PL_08052020.csv')
data_pr = readfile('/content/310522_PR_052020.csv')
data_pp = readfile('/content/310522_PP_201912.csv')
data_pc = readfile('/content/310522_PC_08052020.csv')
# Out:
#    CD_PLANO  CD_MATRICULA_PRINCIPAL  ...  ANOMES_COMPETENCIA  CONTRAPRESTACAO
# 0         3                63620014  ...              202001           350,72
# 1         3                63620103  ...              202001            420,5
# 2         4              8953150092  ...              202001           289,19
# 3         4              8954600091  ...              202001           247,49
# 4         3                63620286  ...              202001           245,52
#
# [5 rows x 5 columns]
# -----------------------------------------------------------------------
# CD_PLANO                       0
# CD_MATRICULA_PRINCIPAL         0
# CD_MATRICULA_SECUNDARIA    56139
# ANOMES_COMPETENCIA             0
# CONTRAPRESTACAO                0
# dtype: int64
# -----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140439 entries, 0 to 140438
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CD_PLANO                 140439 non-null  int64
#  1   CD_MATRICULA_PRINCIPAL   140439 non-null  int64
#  2   CD_MATRICULA_SECUNDARIA  84300 non-null   float64
#  3   ANOMES_COMPETENCIA       140439 non-null  int64
#  4   CONTRAPRESTACAO          140439 non-null  object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 5.4+ MB
# None
# -----------------------------------------------------------------------
#    CD_PLANO  CD_MATRICULA_PRINCIPAL  ...  CD_PRESTADOR CARENCIA
# 0         3                39030369  ...          9612      NaN
# 1         3                28120370  ...          9612      NaN
# 2         3                58060111  ...          9612      NaN
# 3         3                89320344  ...          9612      NaN
# 4         3                 3410293  ...          9612      NaN
#
# [5 rows x 19 columns]
# -----------------------------------------------------------------------
# CD_PLANO                        0
# CD_MATRICULA_PRINCIPAL          0
# CD_MATRICULA_SECUNDARIA    509031
# DT_REALIZADO                    0
# DT_APRESENTACAO                 0
# DT_PAGAMENTO                    0
# TIPO_EVENTO                     0
# NR_GUIA_PRESTADOR            3635
# CLASS_OCOR_SINISTRO             0
# NR_DIARIAS                  29716
# NR_DIARIAS_UTI                  0
# DS_TABELA                   97063
# CD_PROCEDIMENTO                 0
# DESPESA                         0
# REC_CO_PARTICIPACAO        509031
# REC_FRANQUIA               509031
# TIPO_DESPESA                    0
# CD_PRESTADOR                    0
# CARENCIA                   509031
# dtype: int64
# -----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509031 entries, 0 to 509030
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CD_PLANO                 509031 non-null  int64
#  1   CD_MATRICULA_PRINCIPAL   509031 non-null  int64
#  2   CD_MATRICULA_SECUNDARIA  0 non-null       float64
#  3   DT_REALIZADO             509031 non-null  object
#  4   DT_APRESENTACAO          509031 non-null  object
#  5   DT_PAGAMENTO             509031 non-null  object
#  6   TIPO_EVENTO              509031 non-null  int64
#  7   NR_GUIA_PRESTADOR        505396 non-null  object
#  8   CLASS_OCOR_SINISTRO      509031 non-null  int64
#  9   NR_DIARIAS               479315 non-null  float64
#  10  NR_DIARIAS_UTI           509031 non-null  int64
#  11  DS_TABELA                411968 non-null  object
#  12  CD_PROCEDIMENTO          509031 non-null  int64
#  13  DESPESA                  509031 non-null  object
#  14  REC_CO_PARTICIPACAO      0 non-null       float64
#  15  REC_FRANQUIA             0 non-null       float64
#  16  TIPO_DESPESA             509031 non-null  int64
#  17  CD_PRESTADOR             509031 non-null  int64
#  18  CARENCIA                 0 non-null       float64
# dtypes: float64(5), int64(8), object(6)
# memory usage: 73.8+ MB
# None
# -----------------------------------------------------------------------
#    CD_PLANO  CD_MATRICULA  ...  TP_PATROCINIO  HISTORICO
# 0         3      15130100  ...              1          0
# 1         4    8964670238  ...              1          0
# 2         3      75100479  ...              1          0
# 3         3      76310311  ...              1          0
# 4         4    8975190011  ...              1          0
#
# [5 rows x 13 columns]
# -----------------------------------------------------------------------
# CD_PLANO                 0
# CD_MATRICULA             0
# CD_MATRICULA_TEM      7949
# DT_NASCIMENTO            0
# TIPO_BENEFICIARIO        0
# SEXO                     0
# DT_ADESAO                0
# DT_EXCLUSAO          19094
# CPT                      0
# DT_CPT               19634
# CD_EMPRESA               0
# TP_PATROCINIO            0
# HISTORICO                0
# dtype: int64
# -----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19861 entries, 0 to 19860
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CD_PLANO           19861 non-null  int64
#  1   CD_MATRICULA       19861 non-null  int64
#  2   CD_MATRICULA_TEM   11912 non-null  float64
#  3   DT_NASCIMENTO      19861 non-null  int64
#  4   TIPO_BENEFICIARIO  19861 non-null  int64
#  5   SEXO               19861 non-null  int64
#  6   DT_ADESAO          19861 non-null  int64
#  7   DT_EXCLUSAO        767 non-null    float64
#  8   CPT                19861 non-null  int64
#  9   DT_CPT             227 non-null    float64
#  10  CD_EMPRESA         19861 non-null  int64
#  11  TP_PATROCINIO      19861 non-null  int64
#  12  HISTORICO          19861 non-null  int64
# dtypes: float64(3), int64(10)
# memory usage: 2.0 MB
# None
# -----------------------------------------------------------------------
#    CD_PLANO  CD_REGISTRO_MS  ...  CD_MEC_FRANQUIA  CD_MEC_CO_PARTICIPACAO
# 0         3       466898127  ...                0                       0
# 1         4       466899125  ...                0                       0
# 2         5       466738127  ...                0                       0
# 3        10       482600191  ...                0                       0
#
# [4 rows x 11 columns]
# -----------------------------------------------------------------------
# CD_PLANO                     0
# CD_REGISTRO_MS               0
# CD_SEGMENTACAO               0
# CD_PADRAO_ACOMODACAO         0
# CD_TIPO_CONTRATACAO          0
# CD_ABRANGENCIA               0
# CD_MEC_DIRECIONAMENTO        0
# CD_MEC_AUTORIZACAO_PREVIA    0
# CD_MEC_PORTA_ENTRADA         0
# CD_MEC_FRANQUIA              0
# CD_MEC_CO_PARTICIPACAO       0
# dtype: int64
# -----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CD_PLANO                   4 non-null      int64
#  1   CD_REGISTRO_MS             4 non-null      int64
#  2   CD_SEGMENTACAO             4 non-null      int64
#  3   CD_PADRAO_ACOMODACAO       4 non-null      int64
#  4   CD_TIPO_CONTRATACAO        4 non-null      int64
#  5   CD_ABRANGENCIA             4 non-null      int64
#  6   CD_MEC_DIRECIONAMENTO      4 non-null      int64
#  7   CD_MEC_AUTORIZACAO_PREVIA  4 non-null      int64
#  8   CD_MEC_PORTA_ENTRADA       4 non-null      int64
#  9   CD_MEC_FRANQUIA            4 non-null      int64
#  10  CD_MEC_CO_PARTICIPACAO     4 non-null      int64
# dtypes: int64(11)
# memory usage: 480.0 bytes
# None
# -----------------------------------------------------------------------
#    CD_PRESTADOR  ...                                     NOME_PRESTADOR
# 0            99  ...  C&M ASSOCIADOS  SERVIÇOS MÉDICOS LTDA_SANTO AMARO
# 1           999  ...                                          REEMBOLSO
# 2          9030  ...                                       FLEURY S. A.
# 3          9031  ...               AC MILETTO SERVICOS MEDICOS S/C LTDA
# 4          9032  ...  ACFP -  ASSOCIACAO CATARINENSE DOS FUNDOS DE P...
#
# [5 rows x 5 columns]
# -----------------------------------------------------------------------
# CD_PRESTADOR      0
# TIPO_PRESTADOR    0
# TIPO_REDE         0
# CD_IBGE           6
# NOME_PRESTADOR    0
# dtype: int64
# -----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2134 entries, 0 to 2133
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CD_PRESTADOR    2134 non-null   int64
#  1   TIPO_PRESTADOR  2134 non-null   int64
#  2   TIPO_REDE       2134 non-null   int64
#  3   CD_IBGE         2128 non-null   float64
#  4   NOME_PRESTADOR  2134 non-null   object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 83.5+ KB
# None
# -----------------------------------------------------------------------
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xea in position 19: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-26-3b46bd3e1ea5> in <module>()
#      27 data_pl = readfile('/content/310522_PL_08052020.csv')
#      28 data_pr = readfile('/content/310522_PR_052020.csv')
# ---> 29 data_pp = readfile('/content/310522_PP_201912.csv')
#      30 data_pc = readfile('/content/310522_PC_08052020.csv')
#      31
#
# <ipython-input-26-3b46bd3e1ea5> in readfile(path)
#      10     """
#      11     try:
# ---> 12         df = pd.read_csv(path, sep=';', error_bad_lines=False, warn_bad_lines=True)
#      13         print(df.head())
#      14         print('-----------------------------------------------------------------------')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xea in position 19: invalid continuation byte
